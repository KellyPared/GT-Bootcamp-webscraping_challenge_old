# %%
# Import Splinter and BeautifulSoup
from splinter import Browser
from bs4 import BeautifulSoup as bs4
import requests
import pandas as pd
from selenium.webdriver.chrome.service import Service
from selenium import webdriver
from selenium.webdriver.common.by import By
from pprint import pprint 
import csv
import os
import sys
import time
os.path.dirname(sys.executable)
# Out:
# '/Users/kelly.paredes/opt/anaconda3/bin'

# %%
#browser = webdriver.Chrome()
global browser
browser = Browser('chrome')

# %% [markdown]
# ### NASA Mars News

# %%
# Visit the Mars news site: https://static.bc-edx.com/data/web/mars_news/index.html

browser.visit('https://static.bc-edx.com/data/web/mars_news/index.html')
# assign URL
url = "https://static.bc-edx.com/data/web/mars_news/index.html"
browser.visit(url)

# %%
# Beautiful Soup - extraction
html_content = requests.get(url).text

# Create a Beautiful Soup object
soup = bs4(html_content, "html.parser")
print(soup.prettify())
# Extract all the text elements
mars_text = soup.find().text
#print(mars_text)
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <link href="css/bootstrap.min.5.2.2.css" rel="stylesheet" type="text/css"/>
#   <link href="css/font.css" rel="stylesheet" type="text/css"/>
#   <link href="css/app.css" rel="stylesheet" type="text/css"/>
#   <title>
#    News - Mars Exploration Program
#   </title>
#  </head>
#  <body>
#   <div class="col-md-12">
#    <div class="row">
#     <nav class="navbar navbar-expand-lg navbar-light fixed-top">
#      <div class="container-fluid">
#       <a class="navbar-brand" href="#">
#        <img src="images/logo.png" width="80"/>
#        <span class="logo">
#         MARS Planet Science
#        </span>
#        <span class="logo1">
#         Exploration Program
#        </span>
#       </a>
#       <button aria-controls="navbarNav" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler" data-bs-target="#navbarNav" data-bs-toggle="collapse" type="button">
#        <span class="navbar-toggler-icon">
#        </span>
#       </button>
#       <div class="collapse navbar-collapse justify-content-end" id="navbarNav">
#        <ul class="navbar-nav">
#         <li class="nav-item">
#          <a aria-current="page" class="nav-link active" href="#">
#           The Red Planet
#          </a>
#         </li>
#         <li class="nav-item">
#          <a class="nav-link" href="#">
#           The Program
#          </a>
#         </li>
#         <li class="nav-item">
#          <a class="nav-link" href="#">
#           News &amp; Events
#          </a>
#         </li>
#         <li class="nav-item">
#          <a class="nav-link" href="#">
#           Multimedia
#          </a>
#         </li>
#         <li class="nav-item">
#          <a class="nav-link" href="#">
#           Missions
#          </a>
#         </li>
#         <li class="nav-item">
#          <a class="nav-link" href="#">
#           More
#          </a>
#         </li>
#         <li class="nav-item nav_search">
#          <a class="nav-link" href="#">
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </nav>
#     <section class="search">
#      <div class="container">
#       <h1>
#        News
#       </h1>
#       <div class="col-md-12 filter">
#        <div class="row">
#         <div class="col-md-3 search_binder">
#          <input class="search_field" name="search" type="text"/>
#          <input class="search_submit" name="search" type="text"/>
#         </div>
#         <div class="col-md-3">
#          <select aria-label="Default select example" class="form-select" id="year">
#           <option selected="">
#            Latest
#           </option>
#          </select>
#         </div>
#         <div class="col-md-3">
#          <select aria-label="Default select example" class="form-select" id="cat">
#           <option selected="">
#            All Categories
#           </option>
#          </select>
#         </div>
#         <div class="col-md-3">
#         </div>
#        </div>
#       </div>
#      </div>
#     </section>
#     <section class="image_and_description_container">
#      <div class="container" id="news">
#       <div class="col-md-12">
#        <hr/>
#        <div class="row">
#         <div class="col-md-4">
#          <div class="list_image">
#           <img src="images/9299_maven-vertical-limb-320x240.jpeg"/>
#          </div>
#         </div>
#         <div class="col-md-8">
#          <div class="list_text">
#           <div class="list_date">
#            November 9, 2022
#           </div>
#           <div class="content_title">
#            NASA's MAVEN Observes Martian Light Show Caused by Major Solar Storm
#           </div>
#           <div class="article_teaser_body">
#            For the first time in its eight years orbiting Mars, NASAâs MAVEN mission witnessed two different types of ultraviolet aurorae simultaneously, the result of solar storms that began on Aug. 27.
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="col-md-12">
#        <hr/>
#        <div class="row">
#         <div class="col-md-4">
#          <div class="list_image">
#           <img src="images/9292_PIA25287-320x240.jpeg"/>
#          </div>
#         </div>
#         <div class="col-md-8">
#          <div class="list_text">
#           <div class="list_date">
#            November 1, 2022
#           </div>
#           <div class="content_title">
#            NASA Prepares to Say 'Farewell' to InSight Spacecraft
#           </div>
#           <div class="article_teaser_body">
#            A closer look at what goes into wrapping up the mission as the spacecraftâs power supply continues to dwindle.
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="col-md-12">
#        <hr/>
#        <div class="row">
#         <div class="col-md-4">
#          <div class="list_image">
#           <img src="images/9286_PIA25243-320x240.jpeg"/>
#          </div>
#         </div>
#         <div class="col-md-8">
#          <div class="list_text">
#           <div class="list_date">
#            October 28, 2022
#           </div>
#           <div class="content_title">
#            NASA and ESA Agree on Next Steps to Return Mars Samples to Earth
#           </div>
#           <div class="article_teaser_body">
#            The agencyâs Perseverance rover will establish the first sample depot on Mars.
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="col-md-12">
#        <hr/>
#        <div class="row">
#         <div class="col-md-4">
#          <div class="list_image">
#           <img src="images/9289_1-PIA25583320x240.jpeg"/>
#          </div>
#         </div>
#         <div class="col-md-8">
#          <div class="list_text">
#           <div class="list_date">
#            October 27, 2022
#           </div>
#           <div class="content_title">
#            NASA's InSight Lander Detects Stunning Meteoroid Impact on Mars
#           </div>
#           <div class="article_teaser_body">
#            The agencyâs lander felt the ground shake during the impact while cameras aboard the Mars Reconnaissance Orbiter spotted the yawning new crater from space.
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="col-md-12">
#        <hr/>
#        <div class="row">
#         <div class="col-md-4">
#          <div class="list_image">
#           <img src="images/9284_1-PIA25287-320x240.jpeg"/>
#          </div>
#         </div>
#         <div class="col-md-8">
#          <div class="list_text">
#           <div class="list_date">
#            October 21, 2022
#           </div>
#           <div class="content_title">
#            NASA To Host Briefing on InSight, Mars Reconnaissance Orbiter Findings
#           </div>
#           <div class="article_teaser_body">
#            Scientists from two Mars missions will discuss how they combined images and data for a major finding on the Red Planet.
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="col-md-12">
#        <hr/>
#        <div class="row">
#         <div class="col-md-4">
#          <div class="list_image">
#           <img src="images/9283_1-Illustration-of-SHIELD-320x240.jpeg"/>
#          </div>
#         </div>
#         <div class="col-md-8">
#          <div class="list_text">
#           <div class="list_date">
#            October 20, 2022
#           </div>
#           <div class="content_title">
#            Why NASA Is Trying To Crash Land on Mars
#           </div>
#           <div class="article_teaser_body">
#            Like a carâs crumple zone, the experimental SHIELD lander is designed to absorb a hard impact.
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="col-md-12">
#        <hr/>
#        <div class="row">
#         <div class="col-md-4">
#          <div class="list_image">
#           <img src="images/9281_1-PIA25413-320x240.jpeg"/>
#          </div>
#         </div>
#         <div class="col-md-8">
#          <div class="list_text">
#           <div class="list_date">
#            October 19, 2022
#           </div>
#           <div class="content_title">
#            Curiosity Mars Rover Reaches Long-Awaited Salty Region
#           </div>
#           <div class="article_teaser_body">
#            After years of climbing, the Mars rover has arrived at a special region believed to have formed as Marsâ climate was drying.
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="col-md-12">
#        <hr/>
#        <div class="row">
#         <div class="col-md-4">
#          <div class="list_image">
#           <img src="images/9276_PIA25337-320x240.jpeg"/>
#          </div>
#         </div>
#         <div class="col-md-8">
#          <div class="list_text">
#           <div class="list_date">
#            October 12, 2022
#           </div>
#           <div class="content_title">
#            Mars Mission Shields Up for Tests
#           </div>
#           <div class="article_teaser_body">
#            Protecting Mars Sample Return spacecraft from micrometeorites requires high-caliber work.
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="col-md-12">
#        <hr/>
#        <div class="row">
#         <div class="col-md-4">
#          <div class="list_image">
#           <img src="images/9275_PIA25287-clean320x240.jpeg"/>
#          </div>
#         </div>
#         <div class="col-md-8">
#          <div class="list_text">
#           <div class="list_date">
#            October 7, 2022
#           </div>
#           <div class="content_title">
#            NASA's InSight Waits Out Dust Storm
#           </div>
#           <div class="article_teaser_body">
#            InSightâs team is taking steps to help the solar-powered lander continue operating for as long as possible.
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="col-md-12">
#        <hr/>
#        <div class="row">
#         <div class="col-md-4">
#          <div class="list_image">
#           <img src="images/9264_1-PIA25408-320x240.jpeg"/>
#          </div>
#         </div>
#         <div class="col-md-8">
#          <div class="list_text">
#           <div class="list_date">
#            September 19, 2022
#           </div>
#           <div class="content_title">
#            NASA's InSight 'Hears' Its First Meteoroid Impacts on Mars
#           </div>
#           <div class="article_teaser_body">
#            The Mars landerâs seismometer has picked up vibrations from four separate impacts in the past two years.
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="col-md-12">
#        <hr/>
#        <div class="row">
#         <div class="col-md-4">
#          <div class="list_image">
#           <img src="images/9261_26987_PIA24925_MAIN-320x240.jpeg"/>
#          </div>
#         </div>
#         <div class="col-md-8">
#          <div class="list_text">
#           <div class="list_date">
#            September 15, 2022
#           </div>
#           <div class="content_title">
#            NASA's Perseverance Rover Investigates Geologically Rich Mars Terrain
#           </div>
#           <div class="article_teaser_body">
#            The latest findings provide greater detail on a region of the Red Planet that has a watery past and is yielding promising samples for the NASA-ESA Mars Sample Return campaign.
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="col-md-12">
#        <hr/>
#        <div class="row">
#         <div class="col-md-4">
#          <div class="list_image">
#           <img src="images/9257_PIA25325-320x240.jpeg"/>
#          </div>
#         </div>
#         <div class="col-md-8">
#          <div class="list_text">
#           <div class="list_date">
#            September 12, 2022
#           </div>
#           <div class="content_title">
#            NASA to Host Briefing on Perseverance Mars Rover Mission Operations
#           </div>
#           <div class="article_teaser_body">
#            Members of the mission will discuss the roverâs activities as it gathers samples in an ancient river delta.
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="col-md-12">
#        <hr/>
#        <div class="row">
#         <div class="col-md-4">
#          <div class="list_image">
#           <img src="images/9252_1-PIA24836_Perseverance_Selfie_at_Rochette-320x240.jpeg"/>
#          </div>
#         </div>
#         <div class="col-md-8">
#          <div class="list_text">
#           <div class="list_date">
#            August 25, 2022
#           </div>
#           <div class="content_title">
#            NASA's Perseverance Makes New Discoveries in Mars' Jezero Crater
#           </div>
#           <div class="article_teaser_body">
#            The rover found that Jezero Craterâs floor is made up of volcanic rocks that have interacted with water.
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="col-md-12">
#        <hr/>
#        <div class="row">
#         <div class="col-md-4">
#          <div class="list_image">
#           <img src="images/9240_1-PIA25407-Curiositys-360-Degree-Panorama-of-Avanaro-320x240.jpeg"/>
#          </div>
#         </div>
#         <div class="col-md-8">
#          <div class="list_text">
#           <div class="list_date">
#            August 5, 2022
#           </div>
#           <div class="content_title">
#            10 Years Since Landing, NASA's Curiosity Mars Rover Still Has Drive
#           </div>
#           <div class="article_teaser_body">
#            Despite signs of wear, the intrepid spacecraft is about to start an exciting new chapter of its mission as it climbs a Martian mountain.
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="col-md-12">
#        <hr/>
#        <div class="row">
#         <div class="col-md-4">
#          <div class="list_image">
#           <img src="images/9239_article_pictures2_jpeg-320x240.jpeg"/>
#          </div>
#         </div>
#         <div class="col-md-8">
#          <div class="list_text">
#           <div class="list_date">
#            August 4, 2022
#           </div>
#           <div class="content_title">
#            SAM's Top 5 Discoveries Aboard NASA's Curiosity Rover at Mars
#           </div>
#           <div class="article_teaser_body">
#            âSelfieâ of the Curiosity rover with inset showing the SAM instrument prior to installation on the rover.
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#      <hr class="container" style="margin: 25px auto;width: 83%;"/>
#      <button class="btn disable" id="more">
#       More
#      </button>
#     </section>
#     <section class="last_news">
#      <div class="container">
#       <div class="row">
#        <div class="col-12">
#         <h2>
#          You Might Also Like
#         </h2>
#        </div>
#        <div class="col-12">
#         <div class="carousel slide" data-ride="carousel" id="carouselExampleIndicators2">
#          <div class="carousel-inner">
#           <div class="carousel-item active">
#            <div class="row">
#             <div class="col-md-4 mb-3">
#              <div class="card">
#               <img alt="100%x280" class="img-fluid" src="images/9232_1-PIA01551-sojourner-and-ramp-already-in-PJ-320x240.jpeg"/>
#               <div class="card-body">
#                <p class="card-text">
#                 NASA Marks 25 Years Since Pathfinder Touched Down on Mars
#                </p>
#               </div>
#              </div>
#             </div>
#             <div class="col-md-4 mb-3">
#              <div class="card">
#               <img alt="100%x280" class="img-fluid" src="images/9172_PIA25179-320x240.jpeg"/>
#               <div class="card-body">
#                <p class="card-text">
#                 NASA's Perseverance Rover Captures Video of Solar Eclipse on Mars
#                </p>
#               </div>
#              </div>
#             </div>
#             <div class="col-md-4 mb-3">
#              <div class="card">
#               <img alt="100%x280" class="img-fluid" src="images/9167_maven-in-orbit-320x240.jpeg"/>
#               <div class="card-body">
#                <p class="card-text">
#                 NASA, UAE Mars Missions Agree to Share Science Data
#                </p>
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </section>
#     <section class="footer">
#      <div class="container">
#       <div class="col-md-12">
#        <div class="row">
#         <div class="col-md-3">
#          <h5>
#           The Red Planet
#          </h5>
#          <ul>
#           <li>
#            Dashboard
#           </li>
#           <li>
#            Science Goals
#           </li>
#           <li>
#            The Planet
#           </li>
#          </ul>
#         </div>
#         <div class="col-md-3">
#          <h5>
#           The Program
#          </h5>
#          <ul>
#           <li>
#            Mission Statement
#           </li>
#           <li>
#            About the Program
#           </li>
#           <li>
#            Organization Why Mars?
#           </li>
#          </ul>
#         </div>
#         <div class="col-md-3">
#          <h5>
#           Multimedia
#          </h5>
#          <ul>
#           <li>
#            Images
#           </li>
#           <li>
#            Videos
#           </li>
#           <li>
#            More Resources
#           </li>
#          </ul>
#         </div>
#         <div class="col-md-3">
#          <h5>
#           Missions
#          </h5>
#          <ul>
#           <li>
#            Past
#           </li>
#           <li>
#            Present
#           </li>
#           <li>
#            Future
#           </li>
#          </ul>
#         </div>
#        </div>
#       </div>
#      </div>
#     </section>
#     <footer class="footer">
#      <p id="datasource">
#       Images and news content extracted from NASA's
#       <a href="https://mars.nasa.gov/news/">
#        Mars News
#       </a>
#       website on November 9, 2022.
#       <br/>
#       Images used in accordance with the
#       <a href="https://www.jpl.nasa.gov/jpl-image-use-policy">
#        JPL Image Use Policy
#       </a>
#       .
#      </p>
#      <hr>
#       <p id="edx">
#        This site is operated by edX Boot Camps LLC for educational purposes only.
#        <br/>
#        This is not a website endorsed by NASA. This website is intended only for internal academic purposes.
#       </p>
#      </hr>
#     </footer>
#     <script src="js/bootstrap.bundle.min.5.2.2.js">
#     </script>
#    </div>
#   </div>
#  </body>
# </html>

# %%
title_results = soup.find_all('div', class_ = 'content_title')
#soup.find(class_ = 'content_title')
#print(title_results)

# %%
description_results = soup.find_all('div', class_ = 'article_teaser_body')
#print(preview_results)

# %%
# Create an empty list to store the dictionaries
#"title":soup.find_all('title'),
web_texts =[]

for title in title_results:
    for description in description_results:
        web_text_dict = {
            "article_title":title.text,
            "article_teaser": description.text
        }
        web_texts.append(web_text_dict)
web_dictionary = web_texts

# %%
web_dictionary
# Out:
# [{'article_title': "NASA's MAVEN Observes Martian Light Show Caused by Major Solar Storm",
#   'article_teaser': 'For the first time in its eight years orbiting Mars, NASAâ\x80\x99s MAVEN mission witnessed two different types of ultraviolet aurorae simultaneously, the result of solar storms that began on Aug. 27.'},
#  {'article_title': "NASA's MAVEN Observes Martian Light Show Caused by Major Solar Storm",
#   'article_teaser': 'A closer look at what goes into wrapping up the mission as the spacecraftâ\x80\x99s power supply continues to dwindle.'},
#  {'article_title': "NASA's MAVEN Observes Martian Light Show Caused by Major Solar Storm",
#   'article_teaser': 'The agencyâ\x80\x99s Perseverance rover will establish the first sample depot on Mars.'},
#  {'article_title': "NASA's MAVEN Observes Martian Light Show Caused by Major Solar Storm",
#   'article_teaser': 'The agencyâ\x80\x99s lander felt the ground shake during the impact while cameras aboard the Mars Reconnaissance Orbiter spotted the yawning new crater from space.'},
#  {'article_title': "NASA's MAVEN Observes Martian Light Show Caused by Major Solar Storm",
#   'article_teaser': 'Scientists from two Mars missions will discuss how they combined images and data for a major finding on the Red Planet.'},
#  {'article_title': "NASA's MAVEN Observes Martian Light Show Caused by Major Solar Storm",
#   'article_teaser': 'Like a carâ\x80\x99s crumple zone, the experimental SHIELD lander is designed to absorb a hard impact.'},
#  {'article_title': "NASA's MAVEN Observes Martian Light Show Caused by Major Solar Storm",
#   'article_teaser': 'After years of climbing, the Mars rover has arrived at a special region believed to have formed as Marsâ\x80\x99 climate was drying.'},
#  {'article_title': "NASA's MAVEN Observes Martian Light Show Caused by Major Solar Storm",
#   'article_teaser': 'Protecting Mars Sample Return spacecraft from micrometeorites requires high-caliber work.'},
#  {'article_title': "NASA's MAVEN Observes Martian Light Show Caused by Major Solar Storm",
#   'article_teaser': 'InSightâ\x80\x99s team is taking steps to help the solar-powered lander continue operating for as long as possible.'},
#  {'article_title': "NASA's MAVEN Observes Martian Light Show Caused by Major Solar Storm",
#   'article_teaser': 'The Mars landerâ\x80\x99s seismometer has picked up vibrations from four separate impacts in the past two years.'},
#  {'article_title': "NASA's MAVEN Observes Martian Light Show Caused by Major Solar Storm",
#   'article_teaser': 'The latest findings provide greater detail on a region of the Red Planet that has a watery past and is yielding promising samples for the NASA-ESA Mars Sample Return campaign.'},
#  {'article_title': "NASA's MAVEN Observes Martian Light Show Caused by Major Solar Storm",
#   'article_teaser': 'Members of the mission will discuss the roverâ\x80\x99s activities as it gathers samples in an ancient river delta.'},
#  {'article_title': "NASA's MAVEN Observes Martian Light Show Caused by Major Solar Storm",
#   'article_teaser': 'The rover found that Jezero Craterâ\x80\x99s floor is made up of volcanic rocks that have interacted with water.'},
#  {'article_title': "NASA's MAVEN Observes Martian Light Show Caused by Major Solar Storm",
#   'article_teaser': 'Despite signs of wear, the intrepid spacecraft is about to start an exciting new chapter of its mission as it climbs a Martian mountain.'},
#  {'article_title': "NASA's MAVEN Observes Martian Light Show Caused by Major Solar Storm",
#   'article_teaser': 'â\x80\x9cSelfieâ\x80\x9d of the Curiosity rover with inset showing the SAM instrument prior to installation on the rover.'},
#  {'article_title': "NASA Prepares to Say 'Farewell' to InSight Spacecraft",
#   'article_teaser': 'For the first time in its eight years orbiting Mars, NASAâ\x80\x99s MAVEN mission witnessed two different types of ultraviolet aurorae simultaneously, the result of solar storms that began on Aug. 27.'},
#  {'article_title': "NASA Prepares to Say 'Farewell' to InSight Spacecraft",
#   'article_teaser': 'A closer look at what goes into wrapping up the mission as the spacecraftâ\x80\x99s power supply continues to dwindle.'},
#  {'article_title': "NASA Prepares to Say 'Farewell' to InSight Spacecraft",
#   'article_teaser': 'The agencyâ\x80\x99s Perseverance rover will establish the first sample depot on Mars.'},
#  {'article_title': "NASA Prepares to Say 'Farewell' to InSight Spacecraft",
#   'article_teaser': 'The agencyâ\x80\x99s lander felt the ground shake during the impact while cameras aboard the Mars Reconnaissance Orbiter spotted the yawning new crater from space.'},
#  {'article_title': "NASA Prepares to Say 'Farewell' to InSight Spacecraft",
#   'article_teaser': 'Scientists from two Mars missions will discuss how they combined images and data for a major finding on the Red Planet.'},
#  {'article_title': "NASA Prepares to Say 'Farewell' to InSight Spacecraft",
#   'article_teaser': 'Like a carâ\x80\x99s crumple zone, the experimental SHIELD lander is designed to absorb a hard impact.'},
#  {'article_title': "NASA Prepares to Say 'Farewell' to InSight Spacecraft",
#   'article_teaser': 'After years of climbing, the Mars rover has arrived at a special region believed to have formed as Marsâ\x80\x99 climate was drying.'},
#  {'article_title': "NASA Prepares to Say 'Farewell' to InSight Spacecraft",
#   'article_teaser': 'Protecting Mars Sample Return spacecraft from micrometeorites requires high-caliber work.'},
#  {'article_title': "NASA Prepares to Say 'Farewell' to InSight Spacecraft",
#   'article_teaser': 'InSightâ\x80\x99s team is taking steps to help the solar-powered lander continue operating for as long as possible.'},
#  {'article_title': "NASA Prepares to Say 'Farewell' to InSight Spacecraft",
#   'article_teaser': 'The Mars landerâ\x80\x99s seismometer has picked up vibrations from four separate impacts in the past two years.'},
#  {'article_title': "NASA Prepares to Say 'Farewell' to InSight Spacecraft",
#   'article_teaser': 'The latest findings provide greater detail on a region of the Red Planet that has a watery past and is yielding promising samples for the NASA-ESA Mars Sample Return campaign.'},
#  {'article_title': "NASA Prepares to Say 'Farewell' to InSight Spacecraft",
#   'article_teaser': 'Members of the mission will discuss the roverâ\x80\x99s activities as it gathers samples in an ancient river delta.'},
#  {'article_title': "NASA Prepares to Say 'Farewell' to InSight Spacecraft",
#   'article_teaser': 'The rover found that Jezero Craterâ\x80\x99s floor is made up of volcanic rocks that have interacted with water.'},
#  {'article_title': "NASA Prepares to Say 'Farewell' to InSight Spacecraft",
#   'article_teaser': 'Despite signs of wear, the intrepid spacecraft is about to start an exciting new chapter of its mission as it climbs a Martian mountain.'},
#  {'article_title': "NASA Prepares to Say 'Farewell' to InSight Spacecraft",
#   'article_teaser': 'â\x80\x9cSelfieâ\x80\x9d of the Curiosity rover with inset showing the SAM instrument prior to installation on the rover.'},
#  {'article_title': 'NASA and ESA Agree on Next Steps to Return Mars Samples to Earth',
#   'article_teaser': 'For the first time in its eight years orbiting Mars, NASAâ\x80\x99s MAVEN mission witnessed two different types of ultraviolet aurorae simultaneously, the result of solar storms that began on Aug. 27.'},
#  {'article_title': 'NASA and ESA Agree on Next Steps to Return Mars Samples to Earth',
#   'article_teaser': 'A closer look at what goes into wrapping up the mission as the spacecraftâ\x80\x99s power supply continues to dwindle.'},
#  {'article_title': 'NASA and ESA Agree on Next Steps to Return Mars Samples to Earth',
#   'article_teaser': 'The agencyâ\x80\x99s Perseverance rover will establish the first sample depot on Mars.'},
#  {'article_title': 'NASA and ESA Agree on Next Steps to Return Mars Samples to Earth',
#   'article_teaser': 'The agencyâ\x80\x99s lander felt the ground shake during the impact while cameras aboard the Mars Reconnaissance Orbiter spotted the yawning new crater from space.'},
#  {'article_title': 'NASA and ESA Agree on Next Steps to Return Mars Samples to Earth',
#   'article_teaser': 'Scientists from two Mars missions will discuss how they combined images and data for a major finding on the Red Planet.'},
#  {'article_title': 'NASA and ESA Agree on Next Steps to Return Mars Samples to Earth',
#   'article_teaser': 'Like a carâ\x80\x99s crumple zone, the experimental SHIELD lander is designed to absorb a hard impact.'},
#  {'article_title': 'NASA and ESA Agree on Next Steps to Return Mars Samples to Earth',
#   'article_teaser': 'After years of climbing, the Mars rover has arrived at a special region believed to have formed as Marsâ\x80\x99 climate was drying.'},
#  {'article_title': 'NASA and ESA Agree on Next Steps to Return Mars Samples to Earth',
#   'article_teaser': 'Protecting Mars Sample Return spacecraft from micrometeorites requires high-caliber work.'},
#  {'article_title': 'NASA and ESA Agree on Next Steps to Return Mars Samples to Earth',
#   'article_teaser': 'InSightâ\x80\x99s team is taking steps to help the solar-powered lander continue operating for as long as possible.'},
#  {'article_title': 'NASA and ESA Agree on Next Steps to Return Mars Samples to Earth',
#   'article_teaser': 'The Mars landerâ\x80\x99s seismometer has picked up vibrations from four separate impacts in the past two years.'},
#  {'article_title': 'NASA and ESA Agree on Next Steps to Return Mars Samples to Earth',
#   'article_teaser': 'The latest findings provide greater detail on a region of the Red Planet that has a watery past and is yielding promising samples for the NASA-ESA Mars Sample Return campaign.'},
#  {'article_title': 'NASA and ESA Agree on Next Steps to Return Mars Samples to Earth',
#   'article_teaser': 'Members of the mission will discuss the roverâ\x80\x99s activities as it gathers samples in an ancient river delta.'},
#  {'article_title': 'NASA and ESA Agree on Next Steps to Return Mars Samples to Earth',
#   'article_teaser': 'The rover found that Jezero Craterâ\x80\x99s floor is made up of volcanic rocks that have interacted with water.'},
#  {'article_title': 'NASA and ESA Agree on Next Steps to Return Mars Samples to Earth',
#   'article_teaser': 'Despite signs of wear, the intrepid spacecraft is about to start an exciting new chapter of its mission as it climbs a Martian mountain.'},
#  {'article_title': 'NASA and ESA Agree on Next Steps to Return Mars Samples to Earth',
#   'article_teaser': 'â\x80\x9cSelfieâ\x80\x9d of the Curiosity rover with inset showing the SAM instrument prior to installation on the rover.'},
#  {'article_title': "NASA's InSight Lander Detects Stunning Meteoroid Impact on Mars",
#   'article_teaser': 'For the first time in its eight years orbiting Mars, NASAâ\x80\x99s MAVEN mission witnessed two different types of ultraviolet aurorae simultaneously, the result of solar storms that began on Aug. 27.'},
#  {'article_title': "NASA's InSight Lander Detects Stunning Meteoroid Impact on Mars",
#   'article_teaser': 'A closer look at what goes into wrapping up the mission as the spacecraftâ\x80\x99s power supply continues to dwindle.'},
#  {'article_title': "NASA's InSight Lander Detects Stunning Meteoroid Impact on Mars",
#   'article_teaser': 'The agencyâ\x80\x99s Perseverance rover will establish the first sample depot on Mars.'},
#  {'article_title': "NASA's InSight Lander Detects Stunning Meteoroid Impact on Mars",
#   'article_teaser': 'The agencyâ\x80\x99s lander felt the ground shake during the impact while cameras aboard the Mars Reconnaissance Orbiter spotted the yawning new crater from space.'},
#  {'article_title': "NASA's InSight Lander Detects Stunning Meteoroid Impact on Mars",
#   'article_teaser': 'Scientists from two Mars missions will discuss how they combined images and data for a major finding on the Red Planet.'},
#  {'article_title': "NASA's InSight Lander Detects Stunning Meteoroid Impact on Mars",
#   'article_teaser': 'Like a carâ\x80\x99s crumple zone, the experimental SHIELD lander is designed to absorb a hard impact.'},
#  {'article_title': "NASA's InSight Lander Detects Stunning Meteoroid Impact on Mars",
#   'article_teaser': 'After years of climbing, the Mars rover has arrived at a special region believed to have formed as Marsâ\x80\x99 climate was drying.'},
#  {'article_title': "NASA's InSight Lander Detects Stunning Meteoroid Impact on Mars",
#   'article_teaser': 'Protecting Mars Sample Return spacecraft from micrometeorites requires high-caliber work.'},
#  {'article_title': "NASA's InSight Lander Detects Stunning Meteoroid Impact on Mars",
#   'article_teaser': 'InSightâ\x80\x99s team is taking steps to help the solar-powered lander continue operating for as long as possible.'},
#  {'article_title': "NASA's InSight Lander Detects Stunning Meteoroid Impact on Mars",
#   'article_teaser': 'The Mars landerâ\x80\x99s seismometer has picked up vibrations from four separate impacts in the past two years.'},
#  {'article_title': "NASA's InSight Lander Detects Stunning Meteoroid Impact on Mars",
#   'article_teaser': 'The latest findings provide greater detail on a region of the Red Planet that has a watery past and is yielding promising samples for the NASA-ESA Mars Sample Return campaign.'},
#  {'article_title': "NASA's InSight Lander Detects Stunning Meteoroid Impact on Mars",
#   'article_teaser': 'Members of the mission will discuss the roverâ\x80\x99s activities as it gathers samples in an ancient river delta.'},
#  {'article_title': "NASA's InSight Lander Detects Stunning Meteoroid Impact on Mars",
#   'article_teaser': 'The rover found that Jezero Craterâ\x80\x99s floor is made up of volcanic rocks that have interacted with water.'},
#  {'article_title': "NASA's InSight Lander Detects Stunning Meteoroid Impact on Mars",
#   'article_teaser': 'Despite signs of wear, the intrepid spacecraft is about to start an exciting new chapter of its mission as it climbs a Martian mountain.'},
#  {'article_title': "NASA's InSight Lander Detects Stunning Meteoroid Impact on Mars",
#   'article_teaser': 'â\x80\x9cSelfieâ\x80\x9d of the Curiosity rover with inset showing the SAM instrument prior to installation on the rover.'},
#  {'article_title': 'NASA To Host Briefing on InSight, Mars Reconnaissance Orbiter Findings',
#   'article_teaser': 'For the first time in its eight years orbiting Mars, NASAâ\x80\x99s MAVEN mission witnessed two different types of ultraviolet aurorae simultaneously, the result of solar storms that began on Aug. 27.'},
#  {'article_title': 'NASA To Host Briefing on InSight, Mars Reconnaissance Orbiter Findings',
#   'article_teaser': 'A closer look at what goes into wrapping up the mission as the spacecraftâ\x80\x99s power supply continues to dwindle.'},
#  {'article_title': 'NASA To Host Briefing on InSight, Mars Reconnaissance Orbiter Findings',
#   'article_teaser': 'The agencyâ\x80\x99s Perseverance rover will establish the first sample depot on Mars.'},
#  {'article_title': 'NASA To Host Briefing on InSight, Mars Reconnaissance Orbiter Findings',
#   'article_teaser': 'The agencyâ\x80\x99s lander felt the ground shake during the impact while cameras aboard the Mars Reconnaissance Orbiter spotted the yawning new crater from space.'},
#  {'article_title': 'NASA To Host Briefing on InSight, Mars Reconnaissance Orbiter Findings',
#   'article_teaser': 'Scientists from two Mars missions will discuss how they combined images and data for a major finding on the Red Planet.'},
#  {'article_title': 'NASA To Host Briefing on InSight, Mars Reconnaissance Orbiter Findings',
#   'article_teaser': 'Like a carâ\x80\x99s crumple zone, the experimental SHIELD lander is designed to absorb a hard impact.'},
#  {'article_title': 'NASA To Host Briefing on InSight, Mars Reconnaissance Orbiter Findings',
#   'article_teaser': 'After years of climbing, the Mars rover has arrived at a special region believed to have formed as Marsâ\x80\x99 climate was drying.'},
#  {'article_title': 'NASA To Host Briefing on InSight, Mars Reconnaissance Orbiter Findings',
#   'article_teaser': 'Protecting Mars Sample Return spacecraft from micrometeorites requires high-caliber work.'},
#  {'article_title': 'NASA To Host Briefing on InSight, Mars Reconnaissance Orbiter Findings',
#   'article_teaser': 'InSightâ\x80\x99s team is taking steps to help the solar-powered lander continue operating for as long as possible.'},
#  {'article_title': 'NASA To Host Briefing on InSight, Mars Reconnaissance Orbiter Findings',
#   'article_teaser': 'The Mars landerâ\x80\x99s seismometer has picked up vibrations from four separate impacts in the past two years.'},
#  {'article_title': 'NASA To Host Briefing on InSight, Mars Reconnaissance Orbiter Findings',
#   'article_teaser': 'The latest findings provide greater detail on a region of the Red Planet that has a watery past and is yielding promising samples for the NASA-ESA Mars Sample Return campaign.'},
#  {'article_title': 'NASA To Host Briefing on InSight, Mars Reconnaissance Orbiter Findings',
#   'article_teaser': 'Members of the mission will discuss the roverâ\x80\x99s activities as it gathers samples in an ancient river delta.'},
#  {'article_title': 'NASA To Host Briefing on InSight, Mars Reconnaissance Orbiter Findings',
#   'article_teaser': 'The rover found that Jezero Craterâ\x80\x99s floor is made up of volcanic rocks that have interacted with water.'},
#  {'article_title': 'NASA To Host Briefing on InSight, Mars Reconnaissance Orbiter Findings',
#   'article_teaser': 'Despite signs of wear, the intrepid spacecraft is about to start an exciting new chapter of its mission as it climbs a Martian mountain.'},
#  {'article_title': 'NASA To Host Briefing on InSight, Mars Reconnaissance Orbiter Findings',
#   'article_teaser': 'â\x80\x9cSelfieâ\x80\x9d of the Curiosity rover with inset showing the SAM instrument prior to installation on the rover.'},
#  {'article_title': 'Why NASA Is Trying To Crash Land on Mars',
#   'article_teaser': 'For the first time in its eight years orbiting Mars, NASAâ\x80\x99s MAVEN mission witnessed two different types of ultraviolet aurorae simultaneously, the result of solar storms that began on Aug. 27.'},
#  {'article_title': 'Why NASA Is Trying To Crash Land on Mars',
#   'article_teaser': 'A closer look at what goes into wrapping up the mission as the spacecraftâ\x80\x99s power supply continues to dwindle.'},
#  {'article_title': 'Why NASA Is Trying To Crash Land on Mars',
#   'article_teaser': 'The agencyâ\x80\x99s Perseverance rover will establish the first sample depot on Mars.'},
#  {'article_title': 'Why NASA Is Trying To Crash Land on Mars',
#   'article_teaser': 'The agencyâ\x80\x99s lander felt the ground shake during the impact while cameras aboard the Mars Reconnaissance Orbiter spotted the yawning new crater from space.'},
#  {'article_title': 'Why NASA Is Trying To Crash Land on Mars',
#   'article_teaser': 'Scientists from two Mars missions will discuss how they combined images and data for a major finding on the Red Planet.'},
#  {'article_title': 'Why NASA Is Trying To Crash Land on Mars',
#   'article_teaser': 'Like a carâ\x80\x99s crumple zone, the experimental SHIELD lander is designed to absorb a hard impact.'},
#  {'article_title': 'Why NASA Is Trying To Crash Land on Mars',
#   'article_teaser': 'After years of climbing, the Mars rover has arrived at a special region believed to have formed as Marsâ\x80\x99 climate was drying.'},
#  {'article_title': 'Why NASA Is Trying To Crash Land on Mars',
#   'article_teaser': 'Protecting Mars Sample Return spacecraft from micrometeorites requires high-caliber work.'},
#  {'article_title': 'Why NASA Is Trying To Crash Land on Mars',
#   'article_teaser': 'InSightâ\x80\x99s team is taking steps to help the solar-powered lander continue operating for as long as possible.'},
#  {'article_title': 'Why NASA Is Trying To Crash Land on Mars',
#   'article_teaser': 'The Mars landerâ\x80\x99s seismometer has picked up vibrations from four separate impacts in the past two years.'},
#  {'article_title': 'Why NASA Is Trying To Crash Land on Mars',
#   'article_teaser': 'The latest findings provide greater detail on a region of the Red Planet that has a watery past and is yielding promising samples for the NASA-ESA Mars Sample Return campaign.'},
#  {'article_title': 'Why NASA Is Trying To Crash Land on Mars',
#   'article_teaser': 'Members of the mission will discuss the roverâ\x80\x99s activities as it gathers samples in an ancient river delta.'},
#  {'article_title': 'Why NASA Is Trying To Crash Land on Mars',
#   'article_teaser': 'The rover found that Jezero Craterâ\x80\x99s floor is made up of volcanic rocks that have interacted with water.'},
#  {'article_title': 'Why NASA Is Trying To Crash Land on Mars',
#   'article_teaser': 'Despite signs of wear, the intrepid spacecraft is about to start an exciting new chapter of its mission as it climbs a Martian mountain.'},
#  {'article_title': 'Why NASA Is Trying To Crash Land on Mars',
#   'article_teaser': 'â\x80\x9cSelfieâ\x80\x9d of the Curiosity rover with inset showing the SAM instrument prior to installation on the rover.'},
#  {'article_title': 'Curiosity Mars Rover Reaches Long-Awaited Salty Region',
#   'article_teaser': 'For the first time in its eight years orbiting Mars, NASAâ\x80\x99s MAVEN mission witnessed two different types of ultraviolet aurorae simultaneously, the result of solar storms that began on Aug. 27.'},
#  {'article_title': 'Curiosity Mars Rover Reaches Long-Awaited Salty Region',
#   'article_teaser': 'A closer look at what goes into wrapping up the mission as the spacecraftâ\x80\x99s power supply continues to dwindle.'},
#  {'article_title': 'Curiosity Mars Rover Reaches Long-Awaited Salty Region',
#   'article_teaser': 'The agencyâ\x80\x99s Perseverance rover will establish the first sample depot on Mars.'},
#  {'article_title': 'Curiosity Mars Rover Reaches Long-Awaited Salty Region',
#   'article_teaser': 'The agencyâ\x80\x99s lander felt the ground shake during the impact while cameras aboard the Mars Reconnaissance Orbiter spotted the yawning new crater from space.'},
#  {'article_title': 'Curiosity Mars Rover Reaches Long-Awaited Salty Region',
#   'article_teaser': 'Scientists from two Mars missions will discuss how they combined images and data for a major finding on the Red Planet.'},
#  {'article_title': 'Curiosity Mars Rover Reaches Long-Awaited Salty Region',
#   'article_teaser': 'Like a carâ\x80\x99s crumple zone, the experimental SHIELD lander is designed to absorb a hard impact.'},
#  {'article_title': 'Curiosity Mars Rover Reaches Long-Awaited Salty Region',
#   'article_teaser': 'After years of climbing, the Mars rover has arrived at a special region believed to have formed as Marsâ\x80\x99 climate was drying.'},
#  {'article_title': 'Curiosity Mars Rover Reaches Long-Awaited Salty Region',
#   'article_teaser': 'Protecting Mars Sample Return spacecraft from micrometeorites requires high-caliber work.'},
#  {'article_title': 'Curiosity Mars Rover Reaches Long-Awaited Salty Region',
#   'article_teaser': 'InSightâ\x80\x99s team is taking steps to help the solar-powered lander continue operating for as long as possible.'},
#  {'article_title': 'Curiosity Mars Rover Reaches Long-Awaited Salty Region',
#   'article_teaser': 'The Mars landerâ\x80\x99s seismometer has picked up vibrations from four separate impacts in the past two years.'},
#  {'article_title': 'Curiosity Mars Rover Reaches Long-Awaited Salty Region',
#   'article_teaser': 'The latest findings provide greater detail on a region of the Red Planet that has a watery past and is yielding promising samples for the NASA-ESA Mars Sample Return campaign.'},
#  {'article_title': 'Curiosity Mars Rover Reaches Long-Awaited Salty Region',
#   'article_teaser': 'Members of the mission will discuss the roverâ\x80\x99s activities as it gathers samples in an ancient river delta.'},
#  {'article_title': 'Curiosity Mars Rover Reaches Long-Awaited Salty Region',
#   'article_teaser': 'The rover found that Jezero Craterâ\x80\x99s floor is made up of volcanic rocks that have interacted with water.'},
#  {'article_title': 'Curiosity Mars Rover Reaches Long-Awaited Salty Region',
#   'article_teaser': 'Despite signs of wear, the intrepid spacecraft is about to start an exciting new chapter of its mission as it climbs a Martian mountain.'},
#  {'article_title': 'Curiosity Mars Rover Reaches Long-Awaited Salty Region',
#   'article_teaser': 'â\x80\x9cSelfieâ\x80\x9d of the Curiosity rover with inset showing the SAM instrument prior to installation on the rover.'},
#  {'article_title': 'Mars Mission Shields Up for Tests',
#   'article_teaser': 'For the first time in its eight years orbiting Mars, NASAâ\x80\x99s MAVEN mission witnessed two different types of ultraviolet aurorae simultaneously, the result of solar storms that began on Aug. 27.'},
#  {'article_title': 'Mars Mission Shields Up for Tests',
#   'article_teaser': 'A closer look at what goes into wrapping up the mission as the spacecraftâ\x80\x99s power supply continues to dwindle.'},
#  {'article_title': 'Mars Mission Shields Up for Tests',
#   'article_teaser': 'The agencyâ\x80\x99s Perseverance rover will establish the first sample depot on Mars.'},
#  {'article_title': 'Mars Mission Shields Up for Tests',
#   'article_teaser': 'The agencyâ\x80\x99s lander felt the ground shake during the impact while cameras aboard the Mars Reconnaissance Orbiter spotted the yawning new crater from space.'},
#  {'article_title': 'Mars Mission Shields Up for Tests',
#   'article_teaser': 'Scientists from two Mars missions will discuss how they combined images and data for a major finding on the Red Planet.'},
#  {'article_title': 'Mars Mission Shields Up for Tests',
#   'article_teaser': 'Like a carâ\x80\x99s crumple zone, the experimental SHIELD lander is designed to absorb a hard impact.'},
#  {'article_title': 'Mars Mission Shields Up for Tests',
#   'article_teaser': 'After years of climbing, the Mars rover has arrived at a special region believed to have formed as Marsâ\x80\x99 climate was drying.'},
#  {'article_title': 'Mars Mission Shields Up for Tests',
#   'article_teaser': 'Protecting Mars Sample Return spacecraft from micrometeorites requires high-caliber work.'},
#  {'article_title': 'Mars Mission Shields Up for Tests',
#   'article_teaser': 'InSightâ\x80\x99s team is taking steps to help the solar-powered lander continue operating for as long as possible.'},
#  {'article_title': 'Mars Mission Shields Up for Tests',
#   'article_teaser': 'The Mars landerâ\x80\x99s seismometer has picked up vibrations from four separate impacts in the past two years.'},
#  {'article_title': 'Mars Mission Shields Up for Tests',
#   'article_teaser': 'The latest findings provide greater detail on a region of the Red Planet that has a watery past and is yielding promising samples for the NASA-ESA Mars Sample Return campaign.'},
#  {'article_title': 'Mars Mission Shields Up for Tests',
#   'article_teaser': 'Members of the mission will discuss the roverâ\x80\x99s activities as it gathers samples in an ancient river delta.'},
#  {'article_title': 'Mars Mission Shields Up for Tests',
#   'article_teaser': 'The rover found that Jezero Craterâ\x80\x99s floor is made up of volcanic rocks that have interacted with water.'},
#  {'article_title': 'Mars Mission Shields Up for Tests',
#   'article_teaser': 'Despite signs of wear, the intrepid spacecraft is about to start an exciting new chapter of its mission as it climbs a Martian mountain.'},
#  {'article_title': 'Mars Mission Shields Up for Tests',
#   'article_teaser': 'â\x80\x9cSelfieâ\x80\x9d of the Curiosity rover with inset showing the SAM instrument prior to installation on the rover.'},
#  {'article_title': "NASA's InSight Waits Out Dust Storm",
#   'article_teaser': 'For the first time in its eight years orbiting Mars, NASAâ\x80\x99s MAVEN mission witnessed two different types of ultraviolet aurorae simultaneously, the result of solar storms that began on Aug. 27.'},
#  {'article_title': "NASA's InSight Waits Out Dust Storm",
#   'article_teaser': 'A closer look at what goes into wrapping up the mission as the spacecraftâ\x80\x99s power supply continues to dwindle.'},
#  {'article_title': "NASA's InSight Waits Out Dust Storm",
#   'article_teaser': 'The agencyâ\x80\x99s Perseverance rover will establish the first sample depot on Mars.'},
#  {'article_title': "NASA's InSight Waits Out Dust Storm",
#   'article_teaser': 'The agencyâ\x80\x99s lander felt the ground shake during the impact while cameras aboard the Mars Reconnaissance Orbiter spotted the yawning new crater from space.'},
#  {'article_title': "NASA's InSight Waits Out Dust Storm",
#   'article_teaser': 'Scientists from two Mars missions will discuss how they combined images and data for a major finding on the Red Planet.'},
#  {'article_title': "NASA's InSight Waits Out Dust Storm",
#   'article_teaser': 'Like a carâ\x80\x99s crumple zone, the experimental SHIELD lander is designed to absorb a hard impact.'},
#  {'article_title': "NASA's InSight Waits Out Dust Storm",
#   'article_teaser': 'After years of climbing, the Mars rover has arrived at a special region believed to have formed as Marsâ\x80\x99 climate was drying.'},
#  {'article_title': "NASA's InSight Waits Out Dust Storm",
#   'article_teaser': 'Protecting Mars Sample Return spacecraft from micrometeorites requires high-caliber work.'},
#  {'article_title': "NASA's InSight Waits Out Dust Storm",
#   'article_teaser': 'InSightâ\x80\x99s team is taking steps to help the solar-powered lander continue operating for as long as possible.'},
#  {'article_title': "NASA's InSight Waits Out Dust Storm",
#   'article_teaser': 'The Mars landerâ\x80\x99s seismometer has picked up vibrations from four separate impacts in the past two years.'},
#  {'article_title': "NASA's InSight Waits Out Dust Storm",
#   'article_teaser': 'The latest findings provide greater detail on a region of the Red Planet that has a watery past and is yielding promising samples for the NASA-ESA Mars Sample Return campaign.'},
#  {'article_title': "NASA's InSight Waits Out Dust Storm",
#   'article_teaser': 'Members of the mission will discuss the roverâ\x80\x99s activities as it gathers samples in an ancient river delta.'},
#  {'article_title': "NASA's InSight Waits Out Dust Storm",
#   'article_teaser': 'The rover found that Jezero Craterâ\x80\x99s floor is made up of volcanic rocks that have interacted with water.'},
#  {'article_title': "NASA's InSight Waits Out Dust Storm",
#   'article_teaser': 'Despite signs of wear, the intrepid spacecraft is about to start an exciting new chapter of its mission as it climbs a Martian mountain.'},
#  {'article_title': "NASA's InSight Waits Out Dust Storm",
#   'article_teaser': 'â\x80\x9cSelfieâ\x80\x9d of the Curiosity rover with inset showing the SAM instrument prior to installation on the rover.'},
#  {'article_title': "NASA's InSight 'Hears' Its First Meteoroid Impacts on Mars",
#   'article_teaser': 'For the first time in its eight years orbiting Mars, NASAâ\x80\x99s MAVEN mission witnessed two different types of ultraviolet aurorae simultaneously, the result of solar storms that began on Aug. 27.'},
#  {'article_title': "NASA's InSight 'Hears' Its First Meteoroid Impacts on Mars",
#   'article_teaser': 'A closer look at what goes into wrapping up the mission as the spacecraftâ\x80\x99s power supply continues to dwindle.'},
#  {'article_title': "NASA's InSight 'Hears' Its First Meteoroid Impacts on Mars",
#   'article_teaser': 'The agencyâ\x80\x99s Perseverance rover will establish the first sample depot on Mars.'},
#  {'article_title': "NASA's InSight 'Hears' Its First Meteoroid Impacts on Mars",
#   'article_teaser': 'The agencyâ\x80\x99s lander felt the ground shake during the impact while cameras aboard the Mars Reconnaissance Orbiter spotted the yawning new crater from space.'},
#  {'article_title': "NASA's InSight 'Hears' Its First Meteoroid Impacts on Mars",
#   'article_teaser': 'Scientists from two Mars missions will discuss how they combined images and data for a major finding on the Red Planet.'},
#  {'article_title': "NASA's InSight 'Hears' Its First Meteoroid Impacts on Mars",
#   'article_teaser': 'Like a carâ\x80\x99s crumple zone, the experimental SHIELD lander is designed to absorb a hard impact.'},
#  {'article_title': "NASA's InSight 'Hears' Its First Meteoroid Impacts on Mars",
#   'article_teaser': 'After years of climbing, the Mars rover has arrived at a special region believed to have formed as Marsâ\x80\x99 climate was drying.'},
#  {'article_title': "NASA's InSight 'Hears' Its First Meteoroid Impacts on Mars",
#   'article_teaser': 'Protecting Mars Sample Return spacecraft from micrometeorites requires high-caliber work.'},
#  {'article_title': "NASA's InSight 'Hears' Its First Meteoroid Impacts on Mars",
#   'article_teaser': 'InSightâ\x80\x99s team is taking steps to help the solar-powered lander continue operating for as long as possible.'},
#  {'article_title': "NASA's InSight 'Hears' Its First Meteoroid Impacts on Mars",
#   'article_teaser': 'The Mars landerâ\x80\x99s seismometer has picked up vibrations from four separate impacts in the past two years.'},
#  {'article_title': "NASA's InSight 'Hears' Its First Meteoroid Impacts on Mars",
#   'article_teaser': 'The latest findings provide greater detail on a region of the Red Planet that has a watery past and is yielding promising samples for the NASA-ESA Mars Sample Return campaign.'},
#  {'article_title': "NASA's InSight 'Hears' Its First Meteoroid Impacts on Mars",
#   'article_teaser': 'Members of the mission will discuss the roverâ\x80\x99s activities as it gathers samples in an ancient river delta.'},
#  {'article_title': "NASA's InSight 'Hears' Its First Meteoroid Impacts on Mars",
#   'article_teaser': 'The rover found that Jezero Craterâ\x80\x99s floor is made up of volcanic rocks that have interacted with water.'},
#  {'article_title': "NASA's InSight 'Hears' Its First Meteoroid Impacts on Mars",
#   'article_teaser': 'Despite signs of wear, the intrepid spacecraft is about to start an exciting new chapter of its mission as it climbs a Martian mountain.'},
#  {'article_title': "NASA's InSight 'Hears' Its First Meteoroid Impacts on Mars",
#   'article_teaser': 'â\x80\x9cSelfieâ\x80\x9d of the Curiosity rover with inset showing the SAM instrument prior to installation on the rover.'},
#  {'article_title': "NASA's Perseverance Rover Investigates Geologically Rich Mars Terrain",
#   'article_teaser': 'For the first time in its eight years orbiting Mars, NASAâ\x80\x99s MAVEN mission witnessed two different types of ultraviolet aurorae simultaneously, the result of solar storms that began on Aug. 27.'},
#  {'article_title': "NASA's Perseverance Rover Investigates Geologically Rich Mars Terrain",
#   'article_teaser': 'A closer look at what goes into wrapping up the mission as the spacecraftâ\x80\x99s power supply continues to dwindle.'},
#  {'article_title': "NASA's Perseverance Rover Investigates Geologically Rich Mars Terrain",
#   'article_teaser': 'The agencyâ\x80\x99s Perseverance rover will establish the first sample depot on Mars.'},
#  {'article_title': "NASA's Perseverance Rover Investigates Geologically Rich Mars Terrain",
#   'article_teaser': 'The agencyâ\x80\x99s lander felt the ground shake during the impact while cameras aboard the Mars Reconnaissance Orbiter spotted the yawning new crater from space.'},
#  {'article_title': "NASA's Perseverance Rover Investigates Geologically Rich Mars Terrain",
#   'article_teaser': 'Scientists from two Mars missions will discuss how they combined images and data for a major finding on the Red Planet.'},
#  {'article_title': "NASA's Perseverance Rover Investigates Geologically Rich Mars Terrain",
#   'article_teaser': 'Like a carâ\x80\x99s crumple zone, the experimental SHIELD lander is designed to absorb a hard impact.'},
#  {'article_title': "NASA's Perseverance Rover Investigates Geologically Rich Mars Terrain",
#   'article_teaser': 'After years of climbing, the Mars rover has arrived at a special region believed to have formed as Marsâ\x80\x99 climate was drying.'},
#  {'article_title': "NASA's Perseverance Rover Investigates Geologically Rich Mars Terrain",
#   'article_teaser': 'Protecting Mars Sample Return spacecraft from micrometeorites requires high-caliber work.'},
#  {'article_title': "NASA's Perseverance Rover Investigates Geologically Rich Mars Terrain",
#   'article_teaser': 'InSightâ\x80\x99s team is taking steps to help the solar-powered lander continue operating for as long as possible.'},
#  {'article_title': "NASA's Perseverance Rover Investigates Geologically Rich Mars Terrain",
#   'article_teaser': 'The Mars landerâ\x80\x99s seismometer has picked up vibrations from four separate impacts in the past two years.'},
#  {'article_title': "NASA's Perseverance Rover Investigates Geologically Rich Mars Terrain",
#   'article_teaser': 'The latest findings provide greater detail on a region of the Red Planet that has a watery past and is yielding promising samples for the NASA-ESA Mars Sample Return campaign.'},
#  {'article_title': "NASA's Perseverance Rover Investigates Geologically Rich Mars Terrain",
#   'article_teaser': 'Members of the mission will discuss the roverâ\x80\x99s activities as it gathers samples in an ancient river delta.'},
#  {'article_title': "NASA's Perseverance Rover Investigates Geologically Rich Mars Terrain",
#   'article_teaser': 'The rover found that Jezero Craterâ\x80\x99s floor is made up of volcanic rocks that have interacted with water.'},
#  {'article_title': "NASA's Perseverance Rover Investigates Geologically Rich Mars Terrain",
#   'article_teaser': 'Despite signs of wear, the intrepid spacecraft is about to start an exciting new chapter of its mission as it climbs a Martian mountain.'},
#  {'article_title': "NASA's Perseverance Rover Investigates Geologically Rich Mars Terrain",
#   'article_teaser': 'â\x80\x9cSelfieâ\x80\x9d of the Curiosity rover with inset showing the SAM instrument prior to installation on the rover.'},
#  {'article_title': 'NASA to Host Briefing on Perseverance Mars Rover Mission Operations',
#   'article_teaser': 'For the first time in its eight years orbiting Mars, NASAâ\x80\x99s MAVEN mission witnessed two different types of ultraviolet aurorae simultaneously, the result of solar storms that began on Aug. 27.'},
#  {'article_title': 'NASA to Host Briefing on Perseverance Mars Rover Mission Operations',
#   'article_teaser': 'A closer look at what goes into wrapping up the mission as the spacecraftâ\x80\x99s power supply continues to dwindle.'},
#  {'article_title': 'NASA to Host Briefing on Perseverance Mars Rover Mission Operations',
#   'article_teaser': 'The agencyâ\x80\x99s Perseverance rover will establish the first sample depot on Mars.'},
#  {'article_title': 'NASA to Host Briefing on Perseverance Mars Rover Mission Operations',
#   'article_teaser': 'The agencyâ\x80\x99s lander felt the ground shake during the impact while cameras aboard the Mars Reconnaissance Orbiter spotted the yawning new crater from space.'},
#  {'article_title': 'NASA to Host Briefing on Perseverance Mars Rover Mission Operations',
#   'article_teaser': 'Scientists from two Mars missions will discuss how they combined images and data for a major finding on the Red Planet.'},
#  {'article_title': 'NASA to Host Briefing on Perseverance Mars Rover Mission Operations',
#   'article_teaser': 'Like a carâ\x80\x99s crumple zone, the experimental SHIELD lander is designed to absorb a hard impact.'},
#  {'article_title': 'NASA to Host Briefing on Perseverance Mars Rover Mission Operations',
#   'article_teaser': 'After years of climbing, the Mars rover has arrived at a special region believed to have formed as Marsâ\x80\x99 climate was drying.'},
#  {'article_title': 'NASA to Host Briefing on Perseverance Mars Rover Mission Operations',
#   'article_teaser': 'Protecting Mars Sample Return spacecraft from micrometeorites requires high-caliber work.'},
#  {'article_title': 'NASA to Host Briefing on Perseverance Mars Rover Mission Operations',
#   'article_teaser': 'InSightâ\x80\x99s team is taking steps to help the solar-powered lander continue operating for as long as possible.'},
#  {'article_title': 'NASA to Host Briefing on Perseverance Mars Rover Mission Operations',
#   'article_teaser': 'The Mars landerâ\x80\x99s seismometer has picked up vibrations from four separate impacts in the past two years.'},
#  {'article_title': 'NASA to Host Briefing on Perseverance Mars Rover Mission Operations',
#   'article_teaser': 'The latest findings provide greater detail on a region of the Red Planet that has a watery past and is yielding promising samples for the NASA-ESA Mars Sample Return campaign.'},
#  {'article_title': 'NASA to Host Briefing on Perseverance Mars Rover Mission Operations',
#   'article_teaser': 'Members of the mission will discuss the roverâ\x80\x99s activities as it gathers samples in an ancient river delta.'},
#  {'article_title': 'NASA to Host Briefing on Perseverance Mars Rover Mission Operations',
#   'article_teaser': 'The rover found that Jezero Craterâ\x80\x99s floor is made up of volcanic rocks that have interacted with water.'},
#  {'article_title': 'NASA to Host Briefing on Perseverance Mars Rover Mission Operations',
#   'article_teaser': 'Despite signs of wear, the intrepid spacecraft is about to start an exciting new chapter of its mission as it climbs a Martian mountain.'},
#  {'article_title': 'NASA to Host Briefing on Perseverance Mars Rover Mission Operations',
#   'article_teaser': 'â\x80\x9cSelfieâ\x80\x9d of the Curiosity rover with inset showing the SAM instrument prior to installation on the rover.'},
#  {'article_title': "NASA's Perseverance Makes New Discoveries in Mars' Jezero Crater",
#   'article_teaser': 'For the first time in its eight years orbiting Mars, NASAâ\x80\x99s MAVEN mission witnessed two different types of ultraviolet aurorae simultaneously, the result of solar storms that began on Aug. 27.'},
#  {'article_title': "NASA's Perseverance Makes New Discoveries in Mars' Jezero Crater",
#   'article_teaser': 'A closer look at what goes into wrapping up the mission as the spacecraftâ\x80\x99s power supply continues to dwindle.'},
#  {'article_title': "NASA's Perseverance Makes New Discoveries in Mars' Jezero Crater",
#   'article_teaser': 'The agencyâ\x80\x99s Perseverance rover will establish the first sample depot on Mars.'},
#  {'article_title': "NASA's Perseverance Makes New Discoveries in Mars' Jezero Crater",
#   'article_teaser': 'The agencyâ\x80\x99s lander felt the ground shake during the impact while cameras aboard the Mars Reconnaissance Orbiter spotted the yawning new crater from space.'},
#  {'article_title': "NASA's Perseverance Makes New Discoveries in Mars' Jezero Crater",
#   'article_teaser': 'Scientists from two Mars missions will discuss how they combined images and data for a major finding on the Red Planet.'},
#  {'article_title': "NASA's Perseverance Makes New Discoveries in Mars' Jezero Crater",
#   'article_teaser': 'Like a carâ\x80\x99s crumple zone, the experimental SHIELD lander is designed to absorb a hard impact.'},
#  {'article_title': "NASA's Perseverance Makes New Discoveries in Mars' Jezero Crater",
#   'article_teaser': 'After years of climbing, the Mars rover has arrived at a special region believed to have formed as Marsâ\x80\x99 climate was drying.'},
#  {'article_title': "NASA's Perseverance Makes New Discoveries in Mars' Jezero Crater",
#   'article_teaser': 'Protecting Mars Sample Return spacecraft from micrometeorites requires high-caliber work.'},
#  {'article_title': "NASA's Perseverance Makes New Discoveries in Mars' Jezero Crater",
#   'article_teaser': 'InSightâ\x80\x99s team is taking steps to help the solar-powered lander continue operating for as long as possible.'},
#  {'article_title': "NASA's Perseverance Makes New Discoveries in Mars' Jezero Crater",
#   'article_teaser': 'The Mars landerâ\x80\x99s seismometer has picked up vibrations from four separate impacts in the past two years.'},
#  {'article_title': "NASA's Perseverance Makes New Discoveries in Mars' Jezero Crater",
#   'article_teaser': 'The latest findings provide greater detail on a region of the Red Planet that has a watery past and is yielding promising samples for the NASA-ESA Mars Sample Return campaign.'},
#  {'article_title': "NASA's Perseverance Makes New Discoveries in Mars' Jezero Crater",
#   'article_teaser': 'Members of the mission will discuss the roverâ\x80\x99s activities as it gathers samples in an ancient river delta.'},
#  {'article_title': "NASA's Perseverance Makes New Discoveries in Mars' Jezero Crater",
#   'article_teaser': 'The rover found that Jezero Craterâ\x80\x99s floor is made up of volcanic rocks that have interacted with water.'},
#  {'article_title': "NASA's Perseverance Makes New Discoveries in Mars' Jezero Crater",
#   'article_teaser': 'Despite signs of wear, the intrepid spacecraft is about to start an exciting new chapter of its mission as it climbs a Martian mountain.'},
#  {'article_title': "NASA's Perseverance Makes New Discoveries in Mars' Jezero Crater",
#   'article_teaser': 'â\x80\x9cSelfieâ\x80\x9d of the Curiosity rover with inset showing the SAM instrument prior to installation on the rover.'},
#  {'article_title': "10 Years Since Landing, NASA's Curiosity Mars Rover Still Has Drive",
#   'article_teaser': 'For the first time in its eight years orbiting Mars, NASAâ\x80\x99s MAVEN mission witnessed two different types of ultraviolet aurorae simultaneously, the result of solar storms that began on Aug. 27.'},
#  {'article_title': "10 Years Since Landing, NASA's Curiosity Mars Rover Still Has Drive",
#   'article_teaser': 'A closer look at what goes into wrapping up the mission as the spacecraftâ\x80\x99s power supply continues to dwindle.'},
#  {'article_title': "10 Years Since Landing, NASA's Curiosity Mars Rover Still Has Drive",
#   'article_teaser': 'The agencyâ\x80\x99s Perseverance rover will establish the first sample depot on Mars.'},
#  {'article_title': "10 Years Since Landing, NASA's Curiosity Mars Rover Still Has Drive",
#   'article_teaser': 'The agencyâ\x80\x99s lander felt the ground shake during the impact while cameras aboard the Mars Reconnaissance Orbiter spotted the yawning new crater from space.'},
#  {'article_title': "10 Years Since Landing, NASA's Curiosity Mars Rover Still Has Drive",
#   'article_teaser': 'Scientists from two Mars missions will discuss how they combined images and data for a major finding on the Red Planet.'},
#  {'article_title': "10 Years Since Landing, NASA's Curiosity Mars Rover Still Has Drive",
#   'article_teaser': 'Like a carâ\x80\x99s crumple zone, the experimental SHIELD lander is designed to absorb a hard impact.'},
#  {'article_title': "10 Years Since Landing, NASA's Curiosity Mars Rover Still Has Drive",
#   'article_teaser': 'After years of climbing, the Mars rover has arrived at a special region believed to have formed as Marsâ\x80\x99 climate was drying.'},
#  {'article_title': "10 Years Since Landing, NASA's Curiosity Mars Rover Still Has Drive",
#   'article_teaser': 'Protecting Mars Sample Return spacecraft from micrometeorites requires high-caliber work.'},
#  {'article_title': "10 Years Since Landing, NASA's Curiosity Mars Rover Still Has Drive",
#   'article_teaser': 'InSightâ\x80\x99s team is taking steps to help the solar-powered lander continue operating for as long as possible.'},
#  {'article_title': "10 Years Since Landing, NASA's Curiosity Mars Rover Still Has Drive",
#   'article_teaser': 'The Mars landerâ\x80\x99s seismometer has picked up vibrations from four separate impacts in the past two years.'},
#  {'article_title': "10 Years Since Landing, NASA's Curiosity Mars Rover Still Has Drive",
#   'article_teaser': 'The latest findings provide greater detail on a region of the Red Planet that has a watery past and is yielding promising samples for the NASA-ESA Mars Sample Return campaign.'},
#  {'article_title': "10 Years Since Landing, NASA's Curiosity Mars Rover Still Has Drive",
#   'article_teaser': 'Members of the mission will discuss the roverâ\x80\x99s activities as it gathers samples in an ancient river delta.'},
#  {'article_title': "10 Years Since Landing, NASA's Curiosity Mars Rover Still Has Drive",
#   'article_teaser': 'The rover found that Jezero Craterâ\x80\x99s floor is made up of volcanic rocks that have interacted with water.'},
#  {'article_title': "10 Years Since Landing, NASA's Curiosity Mars Rover Still Has Drive",
#   'article_teaser': 'Despite signs of wear, the intrepid spacecraft is about to start an exciting new chapter of its mission as it climbs a Martian mountain.'},
#  {'article_title': "10 Years Since Landing, NASA's Curiosity Mars Rover Still Has Drive",
#   'article_teaser': 'â\x80\x9cSelfieâ\x80\x9d of the Curiosity rover with inset showing the SAM instrument prior to installation on the rover.'},
#  {'article_title': "SAM's Top 5 Discoveries Aboard NASA's Curiosity Rover at Mars",
#   'article_teaser': 'For the first time in its eight years orbiting Mars, NASAâ\x80\x99s MAVEN mission witnessed two different types of ultraviolet aurorae simultaneously, the result of solar storms that began on Aug. 27.'},
#  {'article_title': "SAM's Top 5 Discoveries Aboard NASA's Curiosity Rover at Mars",
#   'article_teaser': 'A closer look at what goes into wrapping up the mission as the spacecraftâ\x80\x99s power supply continues to dwindle.'},
#  {'article_title': "SAM's Top 5 Discoveries Aboard NASA's Curiosity Rover at Mars",
#   'article_teaser': 'The agencyâ\x80\x99s Perseverance rover will establish the first sample depot on Mars.'},
#  {'article_title': "SAM's Top 5 Discoveries Aboard NASA's Curiosity Rover at Mars",
#   'article_teaser': 'The agencyâ\x80\x99s lander felt the ground shake during the impact while cameras aboard the Mars Reconnaissance Orbiter spotted the yawning new crater from space.'},
#  {'article_title': "SAM's Top 5 Discoveries Aboard NASA's Curiosity Rover at Mars",
#   'article_teaser': 'Scientists from two Mars missions will discuss how they combined images and data for a major finding on the Red Planet.'},
#  {'article_title': "SAM's Top 5 Discoveries Aboard NASA's Curiosity Rover at Mars",
#   'article_teaser': 'Like a carâ\x80\x99s crumple zone, the experimental SHIELD lander is designed to absorb a hard impact.'},
#  {'article_title': "SAM's Top 5 Discoveries Aboard NASA's Curiosity Rover at Mars",
#   'article_teaser': 'After years of climbing, the Mars rover has arrived at a special region believed to have formed as Marsâ\x80\x99 climate was drying.'},
#  {'article_title': "SAM's Top 5 Discoveries Aboard NASA's Curiosity Rover at Mars",
#   'article_teaser': 'Protecting Mars Sample Return spacecraft from micrometeorites requires high-caliber work.'},
#  {'article_title': "SAM's Top 5 Discoveries Aboard NASA's Curiosity Rover at Mars",
#   'article_teaser': 'InSightâ\x80\x99s team is taking steps to help the solar-powered lander continue operating for as long as possible.'},
#  {'article_title': "SAM's Top 5 Discoveries Aboard NASA's Curiosity Rover at Mars",
#   'article_teaser': 'The Mars landerâ\x80\x99s seismometer has picked up vibrations from four separate impacts in the past two years.'},
#  {'article_title': "SAM's Top 5 Discoveries Aboard NASA's Curiosity Rover at Mars",
#   'article_teaser': 'The latest findings provide greater detail on a region of the Red Planet that has a watery past and is yielding promising samples for the NASA-ESA Mars Sample Return campaign.'},
#  {'article_title': "SAM's Top 5 Discoveries Aboard NASA's Curiosity Rover at Mars",
#   'article_teaser': 'Members of the mission will discuss the roverâ\x80\x99s activities as it gathers samples in an ancient river delta.'},
#  {'article_title': "SAM's Top 5 Discoveries Aboard NASA's Curiosity Rover at Mars",
#   'article_teaser': 'The rover found that Jezero Craterâ\x80\x99s floor is made up of volcanic rocks that have interacted with water.'},
#  {'article_title': "SAM's Top 5 Discoveries Aboard NASA's Curiosity Rover at Mars",
#   'article_teaser': 'Despite signs of wear, the intrepid spacecraft is about to start an exciting new chapter of its mission as it climbs a Martian mountain.'},
#  {'article_title': "SAM's Top 5 Discoveries Aboard NASA's Curiosity Rover at Mars",
#   'article_teaser': 'â\x80\x9cSelfieâ\x80\x9d of the Curiosity rover with inset showing the SAM instrument prior to installation on the rover.'}]

# %%
with open('resources/articles_data.csv', 'w') as f:
    for single_dict in web_dictionary:
        for key in single_dict.keys():
            f.write("%s,%s\n"%(key,single_dict[key]))

# %% [markdown]
# ### JPL Mars Space Images

# %%
browser.visit('https://spaceimages-mars.com/')
# assign URL
url_image = "https://spaceimages-mars.com/"
browser.visit(url_image)
my_service = Service()

# %%
# assign our HTML elements to variables
#search_button = browser.find_by_text("button", class_="btn btn-outline-light hideimage")
search_button = browser.find_by_xpath('//div[1]/div/a/button')
# click the search button
search_button.click()

# tell python to pause for 10s so we can observe the browser
time.sleep(10)

# %%
#find image /html/body/div[8]/div/div/div/div/img
divs = browser.find_by_tag("class")
within_elements = browser.links.find_by_partial_href("featured")
print(within_elements)
#featured_image_url = 
#print(featured_image_url)

#<a target="_blank" class="showimg fancybox-thumbs" href="image/featured/mars2.jpg"> <button class="btn btn-outline-light"> FULL IMAGE</button></a>
# Out:
# [<splinter.driver.webdriver.WebDriverElement object at 0x7fd3a217ec40>]

# %%
# Beautiful Soup - extraction
html_content = requests.get(url_image).text

# Create a Beautiful Soup object
soup = bs4(html_content, "html.parser")
print(soup.prettify())
# Extract all the text elements
mars_image = soup.find().text
#print(mars_text)
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <link href="https://maxcdn.bootstrapcdn.com/bootstrap/4.0.0/css/bootstrap.min.css" rel="stylesheet"/>
#   <!-- <link rel="stylesheet" type="text/css" href="css/font.css"> -->
#   <link href="css/app.css" rel="stylesheet" type="text/css"/>
#   <link href="https://stackpath.bootstrapcdn.com/font-awesome/4.7.0/css/font-awesome.min.css" rel="stylesheet" type="text/css"/>
#   <title>
#    Space Image
#   </title>
#  </head>
#  <body>
#   <div class="header">
#    <nav class="navbar navbar-expand-lg">
#     <a class="navbar-brand" href="#">
#      <img id="logo" src="image/nasa.png"/>
#      <span class="logo">
#       Jet Propulsion Laboratory
#      </span>
#      <span class="logo1">
#       California Institute of Technology
#      </span>
#     </a>
#     <button aria-controls="navbarNav" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler" data-target="#navbarNav" data-toggle="collapse" type="button">
#      <span class="navbar-toggler-icon">
#      </span>
#     </button>
#     <div class="collapse navbar-collapse justify-content-end" id="navbarNav">
#      <ul class="navbar-nav">
#       <li class="nav-item active">
#        <a class="nav-link" href="#">
#         <i aria-hidden="true" class="fa fa-bars">
#         </i>
#         MENU
#         <i aria-hidden="true" class="fa fa-search">
#         </i>
#        </a>
#       </li>
#      </ul>
#     </div>
#    </nav>
#    <div class="floating_text_area">
#     <h2 class="brand_title">
#      FEATURED IMAGE
#     </h2>
#     <h1 class="media_feature_title">
#      Dusty Space Cloud
#     </h1>
#     <br/>
#     <a class="showimg fancybox-thumbs" href="" target="_blank">
#      <button class="btn btn-outline-light">
#       FULL IMAGE
#      </button>
#     </a>
#    </div>
#   </div>
#   <div class="search sticky">
#    <div class="col-md-12">
#     <div class="row">
#      <div class="col-md-6">
#       <input name="Search" placeholder="Search" type="text"/>
#      </div>
#      <div class="col-md-6">
#       <select aria-label="Default select example" class="form-select" id="options">
#        <option onchange="0" selected="">
#         Mars
#        </option>
#        <!-- <option data-filter="sun" class="button">Mars</option> -->
#        <option class="button" data-filter="Sun">
#         Sun
#        </option>
#        <option class="button" data-filter="earth">
#         Earth
#        </option>
#        <option class="button" data-filter="ida">
#         Ida
#        </option>
#        <option class="button" data-filter="jupiter">
#         Jupiter
#        </option>
#        <option class="button" data-filter="venus">
#         Venus
#        </option>
#       </select>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="container mt-5">
#    <div class="col-md-12">
#     <div class="row">
#      <div class="col-md-6">
#       <h1>
#        Images
#       </h1>
#      </div>
#      <div class="col-md-6" id="icon">
#       <div class="icon2">
#       </div>
#       <div class="icon1">
#       </div>
#      </div>
#     </div>
#    </div>
#    <!-- first div -->
#    <div class="div1" id="filter">
#     <div class="thmbgroup">
#     </div>
#    </div>
#    <!-- first div ends -->
#    <!-- second div starts -->
#    <div class="col-md-12 grid-margin" id="column">
#     <ul class="post-list">
#      <li class="post-heading">
#      </li>
#     </ul>
#    </div>
#    <!-- second div starts -->
#   </div>
#   <div class="first imgcontainer mt-3">
#    <div class="col-md-12">
#     <div class="row">
#      <div class="col-md-3">
#       <img id="pic" src=""/>
#      </div>
#     </div>
#    </div>
#   </div>
#   <!-- end -->
#   <div class="module_gallery container">
#    <div class="col-md-12">
#     <div class="row">
#      <div class="col-md-6">
#       <div class="card">
#        <img alt="Card image cap" class="card-img-top" src="https://www.jpl.nasa.gov/assets/images/content/tmp/images/jpl_photojournal(3x1).jpg"/>
#        <div class="card-body">
#         <h5 class="card-title">
#          JPL Photojournal
#         </h5>
#         <p class="card-text">
#          Access to the full library of publicly released images from various Solar System exploration programs
#         </p>
#        </div>
#       </div>
#      </div>
#      <div class="col-md-6">
#       <div class="card">
#        <img alt="Card image cap" class="card-img-top" src="https://www.jpl.nasa.gov/assets/images/content/tmp/images/nasa_images(3x1).jpg"/>
#        <div class="card-body">
#         <h5 class="card-title">
#          Great images in NASA
#         </h5>
#         <p class="card-text">
#          A selection of the best-known images from a half-century of exploration and discovery
#         </p>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="multi_teaser">
#    <div class="container">
#     <h1>
#      You Might Also Like
#     </h1>
#     <div class="col-md-12 mt-5">
#      <div class="row">
#       <div class="col-md-4">
#        <div class="card">
#         <img alt="Card image cap" class="card-img-top" src="https://imagecache.jpl.nasa.gov/images/640x350/C1-PIA24304---CatScanMars-16-640x350.gif"/>
#         <div class="card-body">
#          <p class="card-text">
#           Access to the full library of publicly released images from various Solar System exploration programs
#          </p>
#         </div>
#        </div>
#       </div>
#       <div class="col-md-4">
#        <div class="card">
#         <img alt="Card image cap" class="card-img-top" src="https://imagecache.jpl.nasa.gov/images/640x350/PIA23491-16-640x350.jpg"/>
#         <div class="card-body">
#          <p class="card-text">
#           Access to the full library of publicly released images from various Solar System exploration programs
#          </p>
#         </div>
#        </div>
#       </div>
#       <div class="col-md-4">
#        <div class="card">
#         <img alt="Card image cap" class="card-img-top" src="https://imagecache.jpl.nasa.gov/images/640x350/C1-PIA23180-16-640x350.gif"/>
#         <div class="card-body">
#          <p class="card-text">
#           Access to the full library of publicly released images from various Solar System exploration programs
#          </p>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="footer">
#    <div class="container">
#     <div class="col-md-12">
#      <div class="row">
#       <div class="col-md-3">
#        <h4>
#         About JPL
#        </h4>
#        <ul>
#         <li>
#          About JPL
#         </li>
#         <li>
#          JPL Vision
#         </li>
#         <li>
#          Executive Council
#         </li>
#         <li>
#          History
#         </li>
#        </ul>
#       </div>
#       <div class="col-md-3">
#        <h4>
#         Education
#        </h4>
#        <ul>
#         <li>
#          Intern
#         </li>
#         <li>
#          Learn
#         </li>
#         <li>
#          Teach
#         </li>
#         <li>
#          News
#         </li>
#        </ul>
#       </div>
#       <div class="col-md-3">
#        <h4>
#         Our Sites
#        </h4>
#        <ul>
#         <li>
#          Asteroid Watch
#         </li>
#         <li>
#          Basics of Spaceflight
#         </li>
#         <li>
#          Cassini - Mission to Saturn
#         </li>
#         <li>
#          Climate Kids
#         </li>
#        </ul>
#       </div>
#       <div class="col-md-3">
#        <h4>
#         Galleries
#        </h4>
#        <ul>
#         <li>
#          JPL Space Images
#         </li>
#         <li>
#          Videos
#         </li>
#         <li>
#          Infographics
#         </li>
#         <li>
#          Photojournal
#         </li>
#        </ul>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <!--<div class="showFullimage">
# 	<button class="btn btn-outline-light hideimage" onclick=hideimage()> Close</button>
# 	<img class="fullimage fade-in" src="">
# </div>-->
#   <!-- <script src="js/jquery.easeScroll.js"></script>  -->
#   <script src="js/jquery-3.5.1.min.js">
#   </script>
#   <!-- <script src="js/jquery-3.2.1.slim.min.js"></script> -->
#   <script src="js/demo.js">
#   </script>
#   <!-- <script src="js/app.js"></script> -->
#   <script src="https://cdnjs.cloudflare.com/ajax/libs/popper.js/1.12.9/umd/popper.min.js">
#   </script>
#   <script src="https://maxcdn.bootstrapcdn.com/bootstrap/4.0.0/js/bootstrap.min.js">
#   </script>
#   <script src="js/fancyBox/jquery.fancybox.pack.js?v=2.1.5" type="text/javascript">
#   </script>
#   <link href="js/fancyBox/jquery.fancybox.css?v=2.1.5" media="screen" rel="stylesheet" type="text/css">
#    <link href="js/fancyBox/helpers/jquery.fancybox-thumbs.css?v=1.0.7" rel="stylesheet" type="text/css">
#     <script src="js/fancyBox/helpers/jquery.fancybox-thumbs.js?v=1.0.7" type="text/javascript">
#     </script>
#    </link>
#   </link>
#  </body>
# </html>

# %% [markdown]
# ### Mars Facts

# %%
#!pip install html5lib

# %%
#https://galaxyfacts-mars.com/

#Pandas to scrape table
url = 'https://galaxyfacts-mars.com/'
all_tables = pd.read_html(url)
print(len(all_tables))
# Out:
# 2

# %%
all_tables[0]
# Out:
#                          0                1                2
# 0  Mars - Earth Comparison             Mars            Earth
# 1                Diameter:         6,779 km        12,742 km
# 2                    Mass:  6.39 × 10^23 kg  5.97 × 10^24 kg
# 3                   Moons:                2                1
# 4       Distance from Sun:   227,943,824 km   149,598,262 km
# 5          Length of Year:   687 Earth days      365.24 days
# 6             Temperature:     -87 to -5 °C      -88 to 58°C

# %%
all_tables[1]
# Out:
#                       0                              1
# 0  Equatorial Diameter:                       6,792 km
# 1       Polar Diameter:                       6,752 km
# 2                 Mass:  6.39 × 10^23 kg (0.11 Earths)
# 3                Moons:          2 ( Phobos & Deimos )
# 4       Orbit Distance:       227,943,824 km (1.38 AU)
# 5         Orbit Period:           687 days (1.9 years)
# 6  Surface Temperature:                   -87 to -5 °C
# 7         First Record:              2nd millennium BC
# 8          Recorded By:           Egyptian astronomers

# %% [markdown]
# ### Mars Hemispheres

# %%
#!pip install selenium

# %%
#browser = webdriver.Chrome()
global browser
browser = Browser('chrome')

# %%
# Beautiful Soup - extraction
url_hemis = 'https://marshemispheres.com/'
html_content = requests.get(url_hemis).text

# Create a Beautiful Soup object
soup = bs4(html_content, "html.parser")
print(soup.prettify())
# Extract all the text elements
mars_image = soup.find().text
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <link href="css/jquery-ui.css" rel="stylesheet" type="text/css"/>
#   <title>
#    Astropedia Search Results | GUSS Astrogeology Science Center
#   </title>
#   <meta content="GUSS Astrogeology Science Center Astropedia search results." name="description"/>
#   <meta content="GUSS,Astrogeology Science Center,Cartography,Geology,Space,Geological Survey,Mapping" name="keywords"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1, maximum-scale=1" name="viewport"/>
#   <link href="css/main.css" media="screen" rel="stylesheet"/>
#   <link href="css/print.css" media="print" rel="stylesheet"/>
#   <link href="#" rel="icon" type="image/x-ico"/>
#  </head>
#  <body id="results">
#   <header>
#    <a href="#" style="float:right;margin-top:10px;" target="_blank">
#     <img alt="USGS: Science for a Changing World" class="logo" height="60" src="images/usgs_logo_main_2x.png"/>
#    </a>
#    <a href="#" style="float:right;margin-top:5px;margin-right:20px;" target="_blank">
#     <img alt="NASA" class="logo" height="65" src="images/nasa-logo-web-med.png"/>
#    </a>
#   </header>
#   <div class="wrapper">
#    <div class="container">
#     <div class="widget block bar">
#      <a href="https://astrogeology.usgs.gov/search" style="float:right;text-decoration:none;">
#       <img alt="Astropedia" src="images/astropedia-logo-main.png" style="width:200px;border:none;float:right;"/>
#       <div style="clear:both;font-size:.8em;float:right;color:#888;">
#        Lunar and Planetary Cartographic Catalog
#       </div>
#      </a>
#      <div style="float:left;height:60px;">
#      </div>
#     </div>
#     <div class="full-content">
#      <section class="block" id="results-accordian">
#       <div class="result-list" data-section="product" id="product-section">
#        <div class="accordian">
#         <h2>
#          Products
#         </h2>
#         <span class="count">
#          4 Results
#         </span>
#         <span class="collapse">
#          Collapse
#         </span>
#        </div>
#        <div class="collapsible results">
#         <div class="item">
#          <a class="itemLink product-item" href="cerberus.html">
#           <img alt="Cerberus Hemisphere Enhanced thumbnail" class="thumb" src="images/39d3266553462198bd2fbc4d18fbed17_cerberus_enhanced.tif_thumb.png"/>
#          </a>
#          <div class="description">
#           <a class="itemLink product-item" href="cerberus.html">
#            <h3>
#             Cerberus Hemisphere Enhanced
#            </h3>
#           </a>
#           <span class="subtitle" style="float:left">
#            image/tiff 21 MB
#           </span>
#           <span class="pubDate" style="float:right">
#           </span>
#           <br/>
#           <p>
#            Mosaic of the Cerberus hemisphere of Mars projected into point perspective, a view similar to that which one would see from a spacecraft. This mosaic is composed of 104 Viking Orbiter images acquiredâ¦
#           </p>
#          </div>
#          <!-- end description -->
#         </div>
#         <div class="item">
#          <a class="itemLink product-item" href="schiaparelli.html">
#           <img alt="Schiaparelli Hemisphere Enhanced thumbnail" class="thumb" src="images/08eac6e22c07fb1fe72223a79252de20_schiaparelli_enhanced.tif_thumb.png"/>
#          </a>
#          <div class="description">
#           <a class="itemLink product-item" href="schiaparelli.html">
#            <h3>
#             Schiaparelli Hemisphere Enhanced
#            </h3>
#           </a>
#           <span class="subtitle" style="float:left">
#            image/tiff 35 MB
#           </span>
#           <span class="pubDate" style="float:right">
#           </span>
#           <br/>
#           <p>
#            Mosaic of the Schiaparelli hemisphere of Mars projected into point perspective, a view similar to that which one would see from a spacecraft. The images were acquired in 1980 during early northernâ¦
#           </p>
#          </div>
#          <!-- end description -->
#         </div>
#         <div class="item">
#          <a class="itemLink product-item" href="syrtis.html">
#           <img alt="Syrtis Major Hemisphere Enhanced thumbnail" class="thumb" src="images/55a0a1e2796313fdeafb17c35925e8ac_syrtis_major_enhanced.tif_thumb.png"/>
#          </a>
#          <div class="description">
#           <a class="itemLink product-item" href="syrtis.html">
#            <h3>
#             Syrtis Major Hemisphere Enhanced
#            </h3>
#           </a>
#           <span class="subtitle" style="float:left">
#            image/tiff 25 MB
#           </span>
#           <span class="pubDate" style="float:right">
#           </span>
#           <br/>
#           <p>
#            Mosaic of the Syrtis Major hemisphere of Mars projected into point perspective, a view similar to that which one would see from a spacecraft. This mosaic is composed of about 100 red and violetâ¦
#           </p>
#          </div>
#          <!-- end description -->
#         </div>
#         <div class="item">
#          <a class="itemLink product-item" href="valles.html">
#           <img alt="Valles Marineris Hemisphere Enhanced thumbnail" class="thumb" src="images/4e59980c1c57f89c680c0e1ccabbeff1_valles_marineris_enhanced.tif_thumb.png"/>
#          </a>
#          <div class="description">
#           <a class="itemLink product-item" href="valles.html">
#            <h3>
#             Valles Marineris Hemisphere Enhanced
#            </h3>
#           </a>
#           <span class="subtitle" style="float:left">
#            image/tiff 27 MB
#           </span>
#           <span class="pubDate" style="float:right">
#           </span>
#           <br/>
#           <p>
#            Mosaic of the Valles Marineris hemisphere of Mars projected into point perspective, a view similar to that which one would see from a spacecraft. The distance is 2500 kilometers from the surface ofâ¦
#           </p>
#          </div>
#          <!-- end description -->
#         </div>
#        </div>
#        <!-- end this-section -->
#       </div>
#      </section>
#     </div>
#     <div class="navigation clear" style="display: none;">
#      <a class="itemLink product-item" href="#" onclick="showMain()">
#       <h3>
#        Back
#       </h3>
#      </a>
#     </div>
#    </div>
#    <footer>
#     <div class="left">
#      <a href="#">
#       Search
#      </a>
#      |
#      <a href="#">
#       About
#      </a>
#      |
#      <a href="#">
#       Contact
#      </a>
#     </div>
#     <div class="right">
#      <a href="#">
#       GUSS Science Center
#      </a>
#     </div>
#    </footer>
#   </div>
#   <div class="page-background" style="
#          background:url('./images/mars.jpg');
#          filter:progid:DXImageTransform.Microsoft.AlphaImageLoader(
#          src='./images/mars.jpg', sizingMethod='scale');
#          ">
#   </div>
#   <script type="text/javascript">
#    var baseUrl = "";
#   </script>
#   <script src="js/jquery.min.js" type="text/javascript">
#   </script>
#   <script src="js/jquery-ui.min.js" type="text/javascript">
#   </script>
#   <script src="js/general.js" type="text/javascript">
#   </script>
#  </body>
# </html>

# %%
search_button = browser.find_by_xpath('//div[1]/div/a/button')
# click the search button
search_button.click()

# tell python to pause for 10s so we can observe the browser
time.sleep(10)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/splinter/element_list.py in __getitem__(self, index)
#      39         try:
# ---> 40             return self._container[index]
#      41         except IndexError:
#
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# ElementDoesNotExist                       Traceback (most recent call last)
# /var/folders/lt/r23wrnp91wx9lpfj7gr25m3rgb08gl/T/ipykernel_1667/2246115771.py in <module>
#       1 search_button = browser.find_by_xpath('//div[1]/div/a/button')
#       2 # click the search button
# ----> 3 search_button.click()
#       4
#       5 # tell python to pause for 10s so we can observe the browser
#
# ~/opt/anaconda3/lib/python3.9/site-packages/splinter/element_list.py in __getattr__(self, name)
#      76     def __getattr__(self, name):
#      77         try:
# ---> 78             return getattr(self.first, name)
#      79         except AttributeError:
#      80             try:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/splinter/element_list.py in first(self)
#      54             >>> assert element_list[0] == element_list.first
#      55         """
# ---> 56         return self[0]
#      57
#      58     @property
#
# ~/opt/anaconda3/lib/python3.9/site-packages/splinter/element_list.py in __getitem__(self, index)
#      40             return self._container[index]
#      41         except IndexError:
# ---> 42             raise ElementDoesNotExist(
#      43                 u'no elements could be found with {0} "{1}"'.format(
#      44                     self.find_by, self.query
#
# ElementDoesNotExist: no elements could be found with xpath "//div[1]/div/a/button"

# %%
link_results = []
#<a href="cerberus.html" class="itemLink product-item"> <h3>Cerberus Hemisphere Enhanced</h3>
title_results = []
for link in soup.findAll(class_='itemLink product-item'):
    l = link.get('href')
    if l in link_results:
        pass
    else:
        link_results.append(f"https://marshemispheres.com/{l}")
for title in soup.findAll(["h3"]):
    title_results.append(f"{title.text}")

print(link_results)
print(title_results)
# Out:
# ['https://marshemispheres.com/cerberus.html', 'https://marshemispheres.com/cerberus.html', 'https://marshemispheres.com/schiaparelli.html', 'https://marshemispheres.com/schiaparelli.html', 'https://marshemispheres.com/syrtis.html', 'https://marshemispheres.com/syrtis.html', 'https://marshemispheres.com/valles.html', 'https://marshemispheres.com/valles.html', 'https://marshemispheres.com/#']
# ['Cerberus Hemisphere Enhanced', 'Schiaparelli Hemisphere Enhanced', 'Syrtis Major Hemisphere Enhanced', 'Valles Marineris Hemisphere Enhanced', 'Back']

# %%
hemispheres_dict = d1={"title":k for k in title_results}

print(hemispheres_dict)
# Out:
# {'title': 'Back'}

# %%
#/html/body/div[1]/div/div[2]/section/div/div[2]/div[1]/a
#//*[@id="product-section"]/div[2]/div[1]/div/a
#click each of the links to the hemispheres

driver = webdriver.Chrome()
driver.get('https://marshemispheres.com/')

# %% [markdown]
# # Use the Latest Version of Selenium

# %%
#<a href="cerberus.html" class="itemLink product-item"><h3>Cerberus Hemisphere Enhanced</h3>
#//*[@id="product-section"]/div[2]/div[1]/div/a/h3                             

search = driver.find_element(By.XPATH,'//*[@id="product-section"]')
search
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/lt/r23wrnp91wx9lpfj7gr25m3rgb08gl/T/ipykernel_1667/2087989115.py in <module>
#       2 #//*[@id="product-section"]/div[2]/div[1]/div/a/h3
#       3
# ----> 4 search = driver.find_element(By.XPATH,'//*[@id="product-section"]')
#       5 search
#
# NameError: name 'driver' is not defined

# %%
for a in driver.find_element(By.XPATH,'//*[@id="product-section"]'):
    print(a.get_attribute('href'))

# %%
# url_hemis = 'https://marshemispheres.com/'

# browser.visit(url_hemis)
# # assign URL
# browser.visit(url_hemis)
# my_service = Service()

# %% [markdown]
# ### MongoDB and Flask Application
